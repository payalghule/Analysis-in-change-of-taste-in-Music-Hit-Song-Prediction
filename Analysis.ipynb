# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('FinalData_1.csv')
data = data[data.Year >= 1960]

# %%
data.head()
# Out:
#              Artist                     Track  Year  Danceability  Energy  \
# 2     Marty Robbins                   El Paso  1960         0.654   0.452
# 3    Frankie Avalon                       Why  1960         0.510   0.349
# 4  Miss Toni Fisher              The Big Hurt  1960         0.624   0.557
# 5    Johnny Preston              Running Bear  1960         0.772   0.297
# 6      Guy Mitchell  Heartaches By The Number  1960         0.584   0.589
#
#    Key  Loudness  Mode  Speechiness  Acousticness  Instrumentalness  Liveness  \
# 2    2    -9.709     1       0.0300         0.835          0.000029     0.160
# 3    5    -8.677     1       0.0264         0.762          0.000000     0.130
# 4    0    -8.309     1       0.0299         0.783          0.000000     0.173
# 5    5   -14.679     0       0.0530         0.854          0.000008     0.125
# 6    5   -11.203     1       0.0718         0.463          0.000015     0.069
#
#    Valence    Tempo
# 2    0.691  106.662
# ...

# %%
vis2
# Out:
#                            Artist                     Track       Year  \
# 2                   Marty Robbins                   El Paso  1960-1970
# 3                  Frankie Avalon                       Why  1960-1970
# 4                Miss Toni Fisher              The Big Hurt  1960-1970
# 5                  Johnny Preston              Running Bear  1960-1970
# 6                    Guy Mitchell  Heartaches By The Number  1960-1970
# ...                           ...                       ...        ...
# 15516                 Keith Urban                   We Were  2010-2020
# 15517                 Niall Horan           Nice To Meet Ya  2010-2020
# 15518                    Sam Hunt                  Kinfolks  2010-2020
# 15519  YoungBoy Never Broke Again                   Hot Now  2010-2020
# 15520                  Luke Bryan    What She Wants Tonight  2010-2020
#
#        Danceability  Energy  Key  Loudness  Mode  Speechiness  Acousticness  \
# ...

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (30,15))
plt.subplot(3,3,1)
sns.lineplot(x = data['Year'], y = data['Acousticness'], label = 'Acousticness')
sns.lineplot(x = data['Year'], y = data['Danceability'], label = 'Danceability')
plt.ylabel('Features')
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (30,15))
plt.subplot(3,3,1)
sns.lineplot(x = data['Year'], y = data['Instrumentalness'], label = 'Instrumentalness')
sns.lineplot(x = data['Year'], y = data['Liveness'], label = 'Liveliness')
plt.ylabel('Features')
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (20,15))
plt.subplot(3,3,1)
sns.lineplot(x = data['Year'], y = data['Danceability'], label = 'Danceability')
plt.ylabel('Features')
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (30,15))
plt.subplot(3,3,1)
sns.lineplot(x = data['Year'], y = data['Speechiness'], label = 'Key')

plt.ylabel('Features')
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (30,25))
plt.subplot(3,3,1)
sns.barplot(x = data['Year'], y = data['Energy'])
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (25,25))
plt.subplot(3,3,1)
sns.barplot(x = data['Year'], y = data['Danceability'])
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (30,15))
plt.subplot(3,3,1)
sns.lineplot(x = data['Year'], y = data['Danceability'], label='Danceability')
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (30,15))
plt.subplot(3,3,1)
sns.barplot(x = data['Year'], y = data['Danceability'], label='Original Series')
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (30,15))
plt.subplot(3,3,1)
sns.barplot(x = data['Year'], y = data['Valence'], label='Original Series')
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (30,15))
plt.subplot(3,3,1)
sns.lineplot(x = data['Year'], y = data['Tempo'], label='Tempo')
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (30,15))
plt.subplot(3,3,1)
sns.lineplot(x = data['Year'], y = data['Instrumentalness'], label='Instrumentalness')
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (30,15))
plt.subplot(3,3,1)
sns.lineplot(x = data['Year'], y = data['Speechiness'], label='Speechiness')
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (30,15))
plt.subplot(3,3,1)
sns.lineplot(x = data['Year'], y = data['Liveness'], label='Original Series')
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (30,15))
plt.subplot(3,3,1)
sns.lineplot(x = data['Year'], y = data['Acousticness'], label='Acousticness')
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (30,15))
plt.subplot(3,3,1)
sns.lineplot(x = data['Year'], y = data['Valence'], label='Valence')
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (30,15))
plt.subplot(3,3,1)
sns.lineplot(x = data['Year'], y = data['Loudness'], label='Loudness')

plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (30,15))
plt.subplot(3,3,1)
sns.lineplot(x = data['Year'], y = data['Valence'], label='Valence')
plt.subplot(3,3,2)
sns.lineplot(x = data['Year'], y = data['Acousticness'], label='Acousticness')
plt.subplot(3,3,4)
sns.lineplot(x = data['Year'], y = data['Energy'], label='Energy')
plt.subplot(3,3,5)
sns.lineplot(x = data['Year'], y = data['Danceability'], label='Danceability')
plt.subplot(3,3,7)
sns.lineplot(x = data['Year'], y = data['Speechiness'], label='Speechiness')
plt.subplot(3,3,8)
sns.lineplot(x = data['Year'], y = data['Loudness'], label='Loudness')

plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (30,15))
plt.subplot(3,3,1)
sns.lineplot(x = data['Year'], y = data['Tempo'], label='Original Series')
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (30,15))
plt.subplot(3,3,1)
sns.lineplot(x = data['Year'], y = data['Energy'], label='Energy')
plt.show()
